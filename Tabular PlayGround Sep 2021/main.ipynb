# %%
import numpy as np
import pandas as pd
from datetime import datetime

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn import preprocessing
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

from xgboost import XGBRegressor, XGBRFRegressor, XGBClassifier

# %%
train_data = pd.read_csv("data/train.csv",index_col = 'id')
test_data = pd.read_csv("data/test.csv",index_col = 'id')

# %%
train_data = train_data.fillna(train_data.mean())
test_data = test_data.fillna(train_data.mean())

# %%
Y_train = train_data['claim'].copy()
X_train = train_data.copy().drop('claim', axis = 1)

# %%
scaler = preprocessing.StandardScaler()

X_train[X_train.columns] = scaler.fit_transform(X_train[X_train.columns])
test_data[test_data.columns] = scaler.transform(test_data[test_data.columns])

# %%
kfold = KFold(n_splits=5, shuffle=False)
model = XGBClassifier(n_estimators=4000,
                          reg_alpha=26,
                          reg_lambda=3,
                          subsample=0.6,
                          colsample_bytree=0.6,
                          max_depth=9,
                          min_child_weight=5,
                          gamma=13.05,
                          learning_rate=0.01,
                          n_jobs=8,
                          booster='gbtree',
                          verbosity=1)
for train_index, test_index in kfold.split(X_train, Y_train):

    model.fit(X_train.iloc[train_index], Y_train.iloc[train_index],
                 early_stopping_rounds=5,
                 eval_metric='auc',
                 eval_set=[(X_train.iloc[train_index], Y_train.iloc[train_index]),(X_train.iloc[test_index], Y_train.iloc[test_index])],
                 verbose=True)
    val_predicts = model.predict(X_train.iloc[test_index])
    roc_value = roc_curve(y_true=Y_train.iloc[test_index], y_score=val_predicts)
    print("Roc Value: ", roc_value)
# Out:
# /Users/volkankasikaralar/.virtualenvs/ML-Practice/lib/python3.6/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.55069	validation_1-auc:0.54038
# [1]	validation_0-auc:0.57025	validation_1-auc:0.55891
# [2]	validation_0-auc:0.58683	validation_1-auc:0.57437
# [3]	validation_0-auc:0.59538	validation_1-auc:0.58140
# [4]	validation_0-auc:0.59897	validation_1-auc:0.58431
# [5]	validation_0-auc:0.60501	validation_1-auc:0.59022
# [6]	validation_0-auc:0.61511	validation_1-auc:0.59993
# [7]	validation_0-auc:0.61880	validation_1-auc:0.60350
# [8]	validation_0-auc:0.62016	validation_1-auc:0.60461
# [9]	validation_0-auc:0.62755	validation_1-auc:0.61178
# [10]	validation_0-auc:0.63214	validation_1-auc:0.61715
# [11]	validation_0-auc:0.63558	validation_1-auc:0.62064
# [12]	validation_0-auc:0.63681	validation_1-auc:0.62142
# [13]	validation_0-auc:0.63798	validation_1-auc:0.62277
# [14]	validation_0-auc:0.64021	validation_1-auc:0.62511
# [15]	validation_0-auc:0.64704	validation_1-auc:0.63180
# [16]	validation_0-auc:0.64814	validation_1-auc:0.63306
# [17]	validation_0-auc:0.64817	validation_1-auc:0.63288
# [18]	validation_0-auc:0.65018	validation_1-auc:0.63438
# [19]	validation_0-auc:0.65018	validation_1-auc:0.63460
# [20]	validation_0-auc:0.65162	validation_1-auc:0.63601
# [21]	validation_0-auc:0.65354	validation_1-auc:0.63792
# [22]	validation_0-auc:0.65582	validation_1-auc:0.64022
# [23]	validation_0-auc:0.65523	validation_1-auc:0.63949
# [24]	validation_0-auc:0.65507	validation_1-auc:0.63951
# [25]	validation_0-auc:0.65638	validation_1-auc:0.64093
# [26]	validation_0-auc:0.65697	validation_1-auc:0.64124
# [27]	validation_0-auc:0.65756	validation_1-auc:0.64165
# [28]	validation_0-auc:0.65992	validation_1-auc:0.64389
# [29]	validation_0-auc:0.66146	validation_1-auc:0.64539
# [30]	validation_0-auc:0.66401	validation_1-auc:0.64821
# [31]	validation_0-auc:0.66427	validation_1-auc:0.64838
# [32]	validation_0-auc:0.66632	validation_1-auc:0.65067
# [33]	validation_0-auc:0.66702	validation_1-auc:0.65163
# [34]	validation_0-auc:0.66771	validation_1-auc:0.65206
# [35]	validation_0-auc:0.66867	validation_1-auc:0.65318
# [36]	validation_0-auc:0.66844	validation_1-auc:0.65295
# [37]	validation_0-auc:0.66903	validation_1-auc:0.65357
# [38]	validation_0-auc:0.66957	validation_1-auc:0.65418
# [39]	validation_0-auc:0.67140	validation_1-auc:0.65601
# [40]	validation_0-auc:0.67222	validation_1-auc:0.65678
# [41]	validation_0-auc:0.67260	validation_1-auc:0.65704
# [42]	validation_0-auc:0.67283	validation_1-auc:0.65722
# [43]	validation_0-auc:0.67374	validation_1-auc:0.65805
# [44]	validation_0-auc:0.67460	validation_1-auc:0.65903
# [45]	validation_0-auc:0.67505	validation_1-auc:0.65958
# [46]	validation_0-auc:0.67496	validation_1-auc:0.65949
# [47]	validation_0-auc:0.67534	validation_1-auc:0.65982
# [48]	validation_0-auc:0.67533	validation_1-auc:0.65991
# [49]	validation_0-auc:0.67619	validation_1-auc:0.66076
# [50]	validation_0-auc:0.67658	validation_1-auc:0.66119
# [51]	validation_0-auc:0.67652	validation_1-auc:0.66117
# [52]	validation_0-auc:0.67686	validation_1-auc:0.66144
# [53]	validation_0-auc:0.67640	validation_1-auc:0.66091
# [54]	validation_0-auc:0.67698	validation_1-auc:0.66149
# [55]	validation_0-auc:0.67804	validation_1-auc:0.66257
# [56]	validation_0-auc:0.67867	validation_1-auc:0.66295
# [57]	validation_0-auc:0.67926	validation_1-auc:0.66352
# [58]	validation_0-auc:0.67916	validation_1-auc:0.66347
# [59]	validation_0-auc:0.67976	validation_1-auc:0.66401
# [60]	validation_0-auc:0.68007	validation_1-auc:0.66424
# [61]	validation_0-auc:0.68049	validation_1-auc:0.66463
# [62]	validation_0-auc:0.68039	validation_1-auc:0.66462
# [63]	validation_0-auc:0.68163	validation_1-auc:0.66592
# [64]	validation_0-auc:0.68166	validation_1-auc:0.66586
# [65]	validation_0-auc:0.68198	validation_1-auc:0.66612
# [66]	validation_0-auc:0.68237	validation_1-auc:0.66639
# [67]	validation_0-auc:0.68321	validation_1-auc:0.66734
# [68]	validation_0-auc:0.68314	validation_1-auc:0.66728
# [69]	validation_0-auc:0.68341	validation_1-auc:0.66745
# [70]	validation_0-auc:0.68369	validation_1-auc:0.66769
# [71]	validation_0-auc:0.68472	validation_1-auc:0.66875
# [72]	validation_0-auc:0.68506	validation_1-auc:0.66909
# [73]	validation_0-auc:0.68555	validation_1-auc:0.66962
# [74]	validation_0-auc:0.68605	validation_1-auc:0.67022
# [75]	validation_0-auc:0.68664	validation_1-auc:0.67077
# [76]	validation_0-auc:0.68694	validation_1-auc:0.67104
# [77]	validation_0-auc:0.68714	validation_1-auc:0.67122
# [78]	validation_0-auc:0.68774	validation_1-auc:0.67176
# [79]	validation_0-auc:0.68840	validation_1-auc:0.67247
# [80]	validation_0-auc:0.68888	validation_1-auc:0.67293
# [81]	validation_0-auc:0.68921	validation_1-auc:0.67318
# [82]	validation_0-auc:0.68923	validation_1-auc:0.67321
# [83]	validation_0-auc:0.68929	validation_1-auc:0.67326
# [84]	validation_0-auc:0.68969	validation_1-auc:0.67366
# [85]	validation_0-auc:0.69027	validation_1-auc:0.67423
# [86]	validation_0-auc:0.69076	validation_1-auc:0.67468
# [87]	validation_0-auc:0.69147	validation_1-auc:0.67542
# [88]	validation_0-auc:0.69202	validation_1-auc:0.67585
# [89]	validation_0-auc:0.69280	validation_1-auc:0.67660
# [90]	validation_0-auc:0.69356	validation_1-auc:0.67739
# [91]	validation_0-auc:0.69364	validation_1-auc:0.67752
# [92]	validation_0-auc:0.69403	validation_1-auc:0.67784
# [93]	validation_0-auc:0.69438	validation_1-auc:0.67814
# [94]	validation_0-auc:0.69544	validation_1-auc:0.67925
# [95]	validation_0-auc:0.69543	validation_1-auc:0.67923
# [96]	validation_0-auc:0.69602	validation_1-auc:0.67980
# [97]	validation_0-auc:0.69644	validation_1-auc:0.68027
# [98]	validation_0-auc:0.69689	validation_1-auc:0.68067
# [99]	validation_0-auc:0.69774	validation_1-auc:0.68154
# [100]	validation_0-auc:0.69787	validation_1-auc:0.68161
# [101]	validation_0-auc:0.69863	validation_1-auc:0.68235
# [102]	validation_0-auc:0.69930	validation_1-auc:0.68298
# [103]	validation_0-auc:0.69979	validation_1-auc:0.68349
# [104]	validation_0-auc:0.70005	validation_1-auc:0.68372
# [105]	validation_0-auc:0.70047	validation_1-auc:0.68415
# [106]	validation_0-auc:0.70088	validation_1-auc:0.68462
# [107]	validation_0-auc:0.70127	validation_1-auc:0.68492
# [108]	validation_0-auc:0.70175	validation_1-auc:0.68540
# [109]	validation_0-auc:0.70227	validation_1-auc:0.68593
# [110]	validation_0-auc:0.70298	validation_1-auc:0.68669
# [111]	validation_0-auc:0.70334	validation_1-auc:0.68696
# [112]	validation_0-auc:0.70359	validation_1-auc:0.68730
# [113]	validation_0-auc:0.70392	validation_1-auc:0.68756
# [114]	validation_0-auc:0.70388	validation_1-auc:0.68753
# [115]	validation_0-auc:0.70411	validation_1-auc:0.68778
# [116]	validation_0-auc:0.70437	validation_1-auc:0.68800
# [117]	validation_0-auc:0.70454	validation_1-auc:0.68815
# [118]	validation_0-auc:0.70536	validation_1-auc:0.68895
# [119]	validation_0-auc:0.70556	validation_1-auc:0.68923
# [120]	validation_0-auc:0.70596	validation_1-auc:0.68964
# [121]	validation_0-auc:0.70640	validation_1-auc:0.69010
# [122]	validation_0-auc:0.70641	validation_1-auc:0.69011
# [123]	validation_0-auc:0.70652	validation_1-auc:0.69027
# [124]	validation_0-auc:0.70686	validation_1-auc:0.69066
# [125]	validation_0-auc:0.70721	validation_1-auc:0.69096
# [126]	validation_0-auc:0.70781	validation_1-auc:0.69152
# [127]	validation_0-auc:0.70847	validation_1-auc:0.69220
# [128]	validation_0-auc:0.70888	validation_1-auc:0.69267
# [129]	validation_0-auc:0.70893	validation_1-auc:0.69273
# [130]	validation_0-auc:0.70934	validation_1-auc:0.69316
# [131]	validation_0-auc:0.70990	validation_1-auc:0.69382
# [132]	validation_0-auc:0.71030	validation_1-auc:0.69427
# [133]	validation_0-auc:0.71047	validation_1-auc:0.69442
# [134]	validation_0-auc:0.71126	validation_1-auc:0.69522
# [135]	validation_0-auc:0.71149	validation_1-auc:0.69550
# [136]	validation_0-auc:0.71186	validation_1-auc:0.69592
# [137]	validation_0-auc:0.71222	validation_1-auc:0.69625
# [138]	validation_0-auc:0.71293	validation_1-auc:0.69690
# [139]	validation_0-auc:0.71319	validation_1-auc:0.69714
# [140]	validation_0-auc:0.71330	validation_1-auc:0.69730
# [141]	validation_0-auc:0.71347	validation_1-auc:0.69748
# [142]	validation_0-auc:0.71360	validation_1-auc:0.69761
# [143]	validation_0-auc:0.71376	validation_1-auc:0.69774
# [144]	validation_0-auc:0.71427	validation_1-auc:0.69827
# [145]	validation_0-auc:0.71455	validation_1-auc:0.69855
# [146]	validation_0-auc:0.71491	validation_1-auc:0.69893
# [147]	validation_0-auc:0.71542	validation_1-auc:0.69943
# [148]	validation_0-auc:0.71584	validation_1-auc:0.69986
# [149]	validation_0-auc:0.71633	validation_1-auc:0.70034
# [150]	validation_0-auc:0.71669	validation_1-auc:0.70064
# [151]	validation_0-auc:0.71718	validation_1-auc:0.70111
# [152]	validation_0-auc:0.71708	validation_1-auc:0.70100
# [153]	validation_0-auc:0.71749	validation_1-auc:0.70140
# [154]	validation_0-auc:0.71786	validation_1-auc:0.70181
# [155]	validation_0-auc:0.71820	validation_1-auc:0.70216
# [156]	validation_0-auc:0.71828	validation_1-auc:0.70224
# [157]	validation_0-auc:0.71875	validation_1-auc:0.70271
# [158]	validation_0-auc:0.71884	validation_1-auc:0.70279
# [159]	validation_0-auc:0.71918	validation_1-auc:0.70314
# [160]	validation_0-auc:0.71946	validation_1-auc:0.70343
# [161]	validation_0-auc:0.71957	validation_1-auc:0.70353
# [162]	validation_0-auc:0.71997	validation_1-auc:0.70392
# [163]	validation_0-auc:0.72011	validation_1-auc:0.70405
# [164]	validation_0-auc:0.72040	validation_1-auc:0.70429
# [165]	validation_0-auc:0.72075	validation_1-auc:0.70469
# [166]	validation_0-auc:0.72077	validation_1-auc:0.70473
# [167]	validation_0-auc:0.72111	validation_1-auc:0.70507
# [168]	validation_0-auc:0.72129	validation_1-auc:0.70526
# [169]	validation_0-auc:0.72177	validation_1-auc:0.70571
# [170]	validation_0-auc:0.72174	validation_1-auc:0.70567
# [171]	validation_0-auc:0.72211	validation_1-auc:0.70599
# [172]	validation_0-auc:0.72225	validation_1-auc:0.70612
# [173]	validation_0-auc:0.72256	validation_1-auc:0.70645
# [174]	validation_0-auc:0.72299	validation_1-auc:0.70690
# [175]	validation_0-auc:0.72344	validation_1-auc:0.70735
# [176]	validation_0-auc:0.72388	validation_1-auc:0.70777
# [177]	validation_0-auc:0.72415	validation_1-auc:0.70807
# [178]	validation_0-auc:0.72446	validation_1-auc:0.70840
# [179]	validation_0-auc:0.72470	validation_1-auc:0.70865
# [180]	validation_0-auc:0.72482	validation_1-auc:0.70873
# [181]	validation_0-auc:0.72514	validation_1-auc:0.70903
# [182]	validation_0-auc:0.72545	validation_1-auc:0.70932
# [183]	validation_0-auc:0.72556	validation_1-auc:0.70944
# [184]	validation_0-auc:0.72600	validation_1-auc:0.70987
# [185]	validation_0-auc:0.72609	validation_1-auc:0.70994
# [186]	validation_0-auc:0.72644	validation_1-auc:0.71028
# [187]	validation_0-auc:0.72649	validation_1-auc:0.71033
# [188]	validation_0-auc:0.72681	validation_1-auc:0.71071
# [189]	validation_0-auc:0.72723	validation_1-auc:0.71113
# [190]	validation_0-auc:0.72735	validation_1-auc:0.71127
# [191]	validation_0-auc:0.72773	validation_1-auc:0.71165
# [192]	validation_0-auc:0.72786	validation_1-auc:0.71175
# [193]	validation_0-auc:0.72838	validation_1-auc:0.71225
# [194]	validation_0-auc:0.72865	validation_1-auc:0.71251
# [195]	validation_0-auc:0.72905	validation_1-auc:0.71293
# [196]	validation_0-auc:0.72933	validation_1-auc:0.71321
# [197]	validation_0-auc:0.72970	validation_1-auc:0.71356
# [198]	validation_0-auc:0.73006	validation_1-auc:0.71391
# [199]	validation_0-auc:0.73017	validation_1-auc:0.71401
# [200]	validation_0-auc:0.73040	validation_1-auc:0.71428
# [201]	validation_0-auc:0.73060	validation_1-auc:0.71449
# [202]	validation_0-auc:0.73083	validation_1-auc:0.71480
# [203]	validation_0-auc:0.73092	validation_1-auc:0.71489
# [204]	validation_0-auc:0.73114	validation_1-auc:0.71511
# [205]	validation_0-auc:0.73123	validation_1-auc:0.71520
# [206]	validation_0-auc:0.73133	validation_1-auc:0.71532
# [207]	validation_0-auc:0.73151	validation_1-auc:0.71548
# [208]	validation_0-auc:0.73177	validation_1-auc:0.71573
# [209]	validation_0-auc:0.73219	validation_1-auc:0.71618
# [210]	validation_0-auc:0.73239	validation_1-auc:0.71640
# [211]	validation_0-auc:0.73269	validation_1-auc:0.71672
# [212]	validation_0-auc:0.73289	validation_1-auc:0.71695
# [213]	validation_0-auc:0.73306	validation_1-auc:0.71711
# [214]	validation_0-auc:0.73319	validation_1-auc:0.71724
# [215]	validation_0-auc:0.73359	validation_1-auc:0.71767
# [216]	validation_0-auc:0.73366	validation_1-auc:0.71773
# [217]	validation_0-auc:0.73388	validation_1-auc:0.71792
# [218]	validation_0-auc:0.73421	validation_1-auc:0.71824
# [219]	validation_0-auc:0.73452	validation_1-auc:0.71853
# [220]	validation_0-auc:0.73469	validation_1-auc:0.71867
# [221]	validation_0-auc:0.73513	validation_1-auc:0.71913
# [222]	validation_0-auc:0.73553	validation_1-auc:0.71958
# [223]	validation_0-auc:0.73572	validation_1-auc:0.71979
# [224]	validation_0-auc:0.73584	validation_1-auc:0.71995
# [225]	validation_0-auc:0.73610	validation_1-auc:0.72018
# [226]	validation_0-auc:0.73636	validation_1-auc:0.72044
# [227]	validation_0-auc:0.73633	validation_1-auc:0.72042
# [228]	validation_0-auc:0.73667	validation_1-auc:0.72082
# [229]	validation_0-auc:0.73682	validation_1-auc:0.72097
# [230]	validation_0-auc:0.73710	validation_1-auc:0.72124
# [231]	validation_0-auc:0.73718	validation_1-auc:0.72134
# [232]	validation_0-auc:0.73752	validation_1-auc:0.72167
# [233]	validation_0-auc:0.73773	validation_1-auc:0.72190
# [234]	validation_0-auc:0.73785	validation_1-auc:0.72201
# [235]	validation_0-auc:0.73795	validation_1-auc:0.72207
# [236]	validation_0-auc:0.73820	validation_1-auc:0.72236
# [237]	validation_0-auc:0.73832	validation_1-auc:0.72250
# [238]	validation_0-auc:0.73842	validation_1-auc:0.72264
# [239]	validation_0-auc:0.73864	validation_1-auc:0.72287
# [240]	validation_0-auc:0.73876	validation_1-auc:0.72297
# [241]	validation_0-auc:0.73897	validation_1-auc:0.72315
# [242]	validation_0-auc:0.73899	validation_1-auc:0.72321
# [243]	validation_0-auc:0.73927	validation_1-auc:0.72352
# [244]	validation_0-auc:0.73943	validation_1-auc:0.72364
# [245]	validation_0-auc:0.73949	validation_1-auc:0.72371
# [246]	validation_0-auc:0.73977	validation_1-auc:0.72400
# [247]	validation_0-auc:0.73996	validation_1-auc:0.72416
# [248]	validation_0-auc:0.74030	validation_1-auc:0.72451
# [249]	validation_0-auc:0.74053	validation_1-auc:0.72476
# [250]	validation_0-auc:0.74047	validation_1-auc:0.72470
# [251]	validation_0-auc:0.74055	validation_1-auc:0.72479
# [252]	validation_0-auc:0.74062	validation_1-auc:0.72487
# [253]	validation_0-auc:0.74083	validation_1-auc:0.72506
# [254]	validation_0-auc:0.74108	validation_1-auc:0.72528
# [255]	validation_0-auc:0.74130	validation_1-auc:0.72544
# [256]	validation_0-auc:0.74144	validation_1-auc:0.72557
# [257]	validation_0-auc:0.74134	validation_1-auc:0.72548
# [258]	validation_0-auc:0.74140	validation_1-auc:0.72555
# [259]	validation_0-auc:0.74147	validation_1-auc:0.72562
# [260]	validation_0-auc:0.74164	validation_1-auc:0.72580
# [261]	validation_0-auc:0.74173	validation_1-auc:0.72588
# [262]	validation_0-auc:0.74186	validation_1-auc:0.72604
# [263]	validation_0-auc:0.74206	validation_1-auc:0.72626
# [264]	validation_0-auc:0.74214	validation_1-auc:0.72634
# [265]	validation_0-auc:0.74238	validation_1-auc:0.72658
# [266]	validation_0-auc:0.74240	validation_1-auc:0.72659
# [267]	validation_0-auc:0.74243	validation_1-auc:0.72663
# [268]	validation_0-auc:0.74273	validation_1-auc:0.72695
# [269]	validation_0-auc:0.74296	validation_1-auc:0.72719
# [270]	validation_0-auc:0.74308	validation_1-auc:0.72731
# [271]	validation_0-auc:0.74317	validation_1-auc:0.72739
# [272]	validation_0-auc:0.74326	validation_1-auc:0.72752
# [273]	validation_0-auc:0.74350	validation_1-auc:0.72777
# [274]	validation_0-auc:0.74364	validation_1-auc:0.72789
# [275]	validation_0-auc:0.74373	validation_1-auc:0.72793
# [276]	validation_0-auc:0.74394	validation_1-auc:0.72816
# [277]	validation_0-auc:0.74398	validation_1-auc:0.72818
# [278]	validation_0-auc:0.74403	validation_1-auc:0.72824
# [279]	validation_0-auc:0.74429	validation_1-auc:0.72846
# [280]	validation_0-auc:0.74446	validation_1-auc:0.72864
# [281]	validation_0-auc:0.74457	validation_1-auc:0.72874
# [282]	validation_0-auc:0.74467	validation_1-auc:0.72887
# [283]	validation_0-auc:0.74485	validation_1-auc:0.72905
# [284]	validation_0-auc:0.74497	validation_1-auc:0.72918
# [285]	validation_0-auc:0.74520	validation_1-auc:0.72942
# [286]	validation_0-auc:0.74530	validation_1-auc:0.72952
# [287]	validation_0-auc:0.74547	validation_1-auc:0.72971
# [288]	validation_0-auc:0.74565	validation_1-auc:0.72988
# [289]	validation_0-auc:0.74574	validation_1-auc:0.72996
# [290]	validation_0-auc:0.74582	validation_1-auc:0.73003
# [291]	validation_0-auc:0.74590	validation_1-auc:0.73009
# [292]	validation_0-auc:0.74606	validation_1-auc:0.73028
# [293]	validation_0-auc:0.74609	validation_1-auc:0.73033
# [294]	validation_0-auc:0.74630	validation_1-auc:0.73056
# [295]	validation_0-auc:0.74639	validation_1-auc:0.73066
# [296]	validation_0-auc:0.74659	validation_1-auc:0.73087
# [297]	validation_0-auc:0.74667	validation_1-auc:0.73097
# [298]	validation_0-auc:0.74687	validation_1-auc:0.73120
# [299]	validation_0-auc:0.74694	validation_1-auc:0.73130
# [300]	validation_0-auc:0.74709	validation_1-auc:0.73146
# [301]	validation_0-auc:0.74719	validation_1-auc:0.73156
# [302]	validation_0-auc:0.74729	validation_1-auc:0.73168
# [303]	validation_0-auc:0.74744	validation_1-auc:0.73184
# [304]	validation_0-auc:0.74759	validation_1-auc:0.73199
# [305]	validation_0-auc:0.74761	validation_1-auc:0.73201
# [306]	validation_0-auc:0.74778	validation_1-auc:0.73217
# [307]	validation_0-auc:0.74778	validation_1-auc:0.73219
# [308]	validation_0-auc:0.74800	validation_1-auc:0.73242
# [309]	validation_0-auc:0.74813	validation_1-auc:0.73256
# [310]	validation_0-auc:0.74840	validation_1-auc:0.73284
# [311]	validation_0-auc:0.74838	validation_1-auc:0.73283
# [312]	validation_0-auc:0.74847	validation_1-auc:0.73292
# [313]	validation_0-auc:0.74866	validation_1-auc:0.73314
# [314]	validation_0-auc:0.74896	validation_1-auc:0.73344
# [315]	validation_0-auc:0.74912	validation_1-auc:0.73359
# [316]	validation_0-auc:0.74916	validation_1-auc:0.73363
# [317]	validation_0-auc:0.74932	validation_1-auc:0.73378
# [318]	validation_0-auc:0.74929	validation_1-auc:0.73373
# [319]	validation_0-auc:0.74947	validation_1-auc:0.73394
# [320]	validation_0-auc:0.74953	validation_1-auc:0.73399
# [321]	validation_0-auc:0.74956	validation_1-auc:0.73402
# [322]	validation_0-auc:0.74973	validation_1-auc:0.73418
# [323]	validation_0-auc:0.74986	validation_1-auc:0.73432
# [324]	validation_0-auc:0.75001	validation_1-auc:0.73450
# [325]	validation_0-auc:0.75029	validation_1-auc:0.73480
# [326]	validation_0-auc:0.75053	validation_1-auc:0.73499
# [327]	validation_0-auc:0.75073	validation_1-auc:0.73518
# [328]	validation_0-auc:0.75093	validation_1-auc:0.73543
# [329]	validation_0-auc:0.75107	validation_1-auc:0.73558
# [330]	validation_0-auc:0.75108	validation_1-auc:0.73559
# [331]	validation_0-auc:0.75116	validation_1-auc:0.73568
# [332]	validation_0-auc:0.75129	validation_1-auc:0.73580
# [333]	validation_0-auc:0.75140	validation_1-auc:0.73596
# [334]	validation_0-auc:0.75155	validation_1-auc:0.73613
# [335]	validation_0-auc:0.75164	validation_1-auc:0.73620
# [336]	validation_0-auc:0.75182	validation_1-auc:0.73638
# [337]	validation_0-auc:0.75186	validation_1-auc:0.73642
# [338]	validation_0-auc:0.75184	validation_1-auc:0.73640
# [339]	validation_0-auc:0.75201	validation_1-auc:0.73656
# [340]	validation_0-auc:0.75217	validation_1-auc:0.73670
# [341]	validation_0-auc:0.75222	validation_1-auc:0.73673
# [342]	validation_0-auc:0.75226	validation_1-auc:0.73674
# [343]	validation_0-auc:0.75249	validation_1-auc:0.73698
# [344]	validation_0-auc:0.75257	validation_1-auc:0.73707
# [345]	validation_0-auc:0.75283	validation_1-auc:0.73737
# [346]	validation_0-auc:0.75297	validation_1-auc:0.73750
# [347]	validation_0-auc:0.75312	validation_1-auc:0.73766
# [348]	validation_0-auc:0.75323	validation_1-auc:0.73782
# [349]	validation_0-auc:0.75339	validation_1-auc:0.73799
# [350]	validation_0-auc:0.75360	validation_1-auc:0.73822
# [351]	validation_0-auc:0.75376	validation_1-auc:0.73838
# [352]	validation_0-auc:0.75403	validation_1-auc:0.73867
# [353]	validation_0-auc:0.75411	validation_1-auc:0.73874
# [354]	validation_0-auc:0.75432	validation_1-auc:0.73897
# [355]	validation_0-auc:0.75441	validation_1-auc:0.73905
# [356]	validation_0-auc:0.75453	validation_1-auc:0.73917
# [357]	validation_0-auc:0.75456	validation_1-auc:0.73920
# [358]	validation_0-auc:0.75467	validation_1-auc:0.73930
# [359]	validation_0-auc:0.75492	validation_1-auc:0.73953
# [360]	validation_0-auc:0.75512	validation_1-auc:0.73975
# [361]	validation_0-auc:0.75536	validation_1-auc:0.74001
# [362]	validation_0-auc:0.75544	validation_1-auc:0.74008
# [363]	validation_0-auc:0.75571	validation_1-auc:0.74036
# [364]	validation_0-auc:0.75580	validation_1-auc:0.74046
# [365]	validation_0-auc:0.75600	validation_1-auc:0.74068
# [366]	validation_0-auc:0.75615	validation_1-auc:0.74083
# [367]	validation_0-auc:0.75622	validation_1-auc:0.74089
# [368]	validation_0-auc:0.75627	validation_1-auc:0.74096
# [369]	validation_0-auc:0.75636	validation_1-auc:0.74105
# [370]	validation_0-auc:0.75638	validation_1-auc:0.74108
# [371]	validation_0-auc:0.75644	validation_1-auc:0.74114
# [372]	validation_0-auc:0.75653	validation_1-auc:0.74122
# [373]	validation_0-auc:0.75655	validation_1-auc:0.74123
# [374]	validation_0-auc:0.75674	validation_1-auc:0.74142
# [375]	validation_0-auc:0.75677	validation_1-auc:0.74144
# [376]	validation_0-auc:0.75690	validation_1-auc:0.74160
# [377]	validation_0-auc:0.75702	validation_1-auc:0.74170
# [378]	validation_0-auc:0.75718	validation_1-auc:0.74189
# [379]	validation_0-auc:0.75738	validation_1-auc:0.74210
# [380]	validation_0-auc:0.75748	validation_1-auc:0.74221
# [381]	validation_0-auc:0.75756	validation_1-auc:0.74230
# [382]	validation_0-auc:0.75774	validation_1-auc:0.74247
# [383]	validation_0-auc:0.75782	validation_1-auc:0.74254
# [384]	validation_0-auc:0.75789	validation_1-auc:0.74262
# [385]	validation_0-auc:0.75808	validation_1-auc:0.74283
# [386]	validation_0-auc:0.75828	validation_1-auc:0.74303
# [387]	validation_0-auc:0.75837	validation_1-auc:0.74312
# [388]	validation_0-auc:0.75861	validation_1-auc:0.74336
# [389]	validation_0-auc:0.75877	validation_1-auc:0.74352
# [390]	validation_0-auc:0.75892	validation_1-auc:0.74368
# [391]	validation_0-auc:0.75905	validation_1-auc:0.74383
# [392]	validation_0-auc:0.75919	validation_1-auc:0.74398
# [393]	validation_0-auc:0.75928	validation_1-auc:0.74407
# [394]	validation_0-auc:0.75943	validation_1-auc:0.74423
# [395]	validation_0-auc:0.75947	validation_1-auc:0.74428
# [396]	validation_0-auc:0.75949	validation_1-auc:0.74429
# [397]	validation_0-auc:0.75957	validation_1-auc:0.74437
# [398]	validation_0-auc:0.75974	validation_1-auc:0.74456
# [399]	validation_0-auc:0.75984	validation_1-auc:0.74464
# [400]	validation_0-auc:0.75996	validation_1-auc:0.74479
# [401]	validation_0-auc:0.76017	validation_1-auc:0.74501
# [402]	validation_0-auc:0.76040	validation_1-auc:0.74526
# [403]	validation_0-auc:0.76043	validation_1-auc:0.74530
# [404]	validation_0-auc:0.76051	validation_1-auc:0.74540
# [405]	validation_0-auc:0.76060	validation_1-auc:0.74548
# [406]	validation_0-auc:0.76060	validation_1-auc:0.74545
# [407]	validation_0-auc:0.76070	validation_1-auc:0.74558
# [408]	validation_0-auc:0.76085	validation_1-auc:0.74575
# [409]	validation_0-auc:0.76083	validation_1-auc:0.74573
# [410]	validation_0-auc:0.76094	validation_1-auc:0.74585
# [411]	validation_0-auc:0.76111	validation_1-auc:0.74605
# [412]	validation_0-auc:0.76116	validation_1-auc:0.74612
# [413]	validation_0-auc:0.76133	validation_1-auc:0.74630
# [414]	validation_0-auc:0.76153	validation_1-auc:0.74651
# [415]	validation_0-auc:0.76163	validation_1-auc:0.74663
# [416]	validation_0-auc:0.76185	validation_1-auc:0.74683
# [417]	validation_0-auc:0.76197	validation_1-auc:0.74695
# [418]	validation_0-auc:0.76210	validation_1-auc:0.74706
# [419]	validation_0-auc:0.76222	validation_1-auc:0.74719
# [420]	validation_0-auc:0.76221	validation_1-auc:0.74719
# [421]	validation_0-auc:0.76219	validation_1-auc:0.74714
# [422]	validation_0-auc:0.76234	validation_1-auc:0.74732
# [423]	validation_0-auc:0.76236	validation_1-auc:0.74737
# [424]	validation_0-auc:0.76242	validation_1-auc:0.74743
# [425]	validation_0-auc:0.76245	validation_1-auc:0.74746
# [426]	validation_0-auc:0.76247	validation_1-auc:0.74747
# [427]	validation_0-auc:0.76255	validation_1-auc:0.74755
# [428]	validation_0-auc:0.76270	validation_1-auc:0.74771
# [429]	validation_0-auc:0.76284	validation_1-auc:0.74784
# [430]	validation_0-auc:0.76291	validation_1-auc:0.74794
# [431]	validation_0-auc:0.76302	validation_1-auc:0.74804
# [432]	validation_0-auc:0.76315	validation_1-auc:0.74818
# [433]	validation_0-auc:0.76313	validation_1-auc:0.74817
# [434]	validation_0-auc:0.76317	validation_1-auc:0.74821
# [435]	validation_0-auc:0.76329	validation_1-auc:0.74831
# [436]	validation_0-auc:0.76336	validation_1-auc:0.74838
# [437]	validation_0-auc:0.76342	validation_1-auc:0.74846
# [438]	validation_0-auc:0.76352	validation_1-auc:0.74855
# [439]	validation_0-auc:0.76360	validation_1-auc:0.74863
# [440]	validation_0-auc:0.76368	validation_1-auc:0.74873
# [441]	validation_0-auc:0.76382	validation_1-auc:0.74887
# [442]	validation_0-auc:0.76384	validation_1-auc:0.74889
# [443]	validation_0-auc:0.76390	validation_1-auc:0.74895
# [444]	validation_0-auc:0.76401	validation_1-auc:0.74908
# [445]	validation_0-auc:0.76412	validation_1-auc:0.74921
# [446]	validation_0-auc:0.76416	validation_1-auc:0.74924
# [447]	validation_0-auc:0.76427	validation_1-auc:0.74934
# [448]	validation_0-auc:0.76435	validation_1-auc:0.74943
# [449]	validation_0-auc:0.76448	validation_1-auc:0.74954
# [450]	validation_0-auc:0.76457	validation_1-auc:0.74963
# [451]	validation_0-auc:0.76462	validation_1-auc:0.74970
# [452]	validation_0-auc:0.76467	validation_1-auc:0.74974
# [453]	validation_0-auc:0.76474	validation_1-auc:0.74983
# [454]	validation_0-auc:0.76484	validation_1-auc:0.74992
# [455]	validation_0-auc:0.76502	validation_1-auc:0.75013
# [456]	validation_0-auc:0.76515	validation_1-auc:0.75026
# [457]	validation_0-auc:0.76514	validation_1-auc:0.75026
# [458]	validation_0-auc:0.76526	validation_1-auc:0.75039
# [459]	validation_0-auc:0.76539	validation_1-auc:0.75050
# [460]	validation_0-auc:0.76543	validation_1-auc:0.75057
# [461]	validation_0-auc:0.76540	validation_1-auc:0.75055
# [462]	validation_0-auc:0.76545	validation_1-auc:0.75057
# [463]	validation_0-auc:0.76544	validation_1-auc:0.75055
# [464]	validation_0-auc:0.76550	validation_1-auc:0.75062
# [465]	validation_0-auc:0.76553	validation_1-auc:0.75066
# [466]	validation_0-auc:0.76560	validation_1-auc:0.75073
# [467]	validation_0-auc:0.76571	validation_1-auc:0.75086
# [468]	validation_0-auc:0.76582	validation_1-auc:0.75098
# [469]	validation_0-auc:0.76594	validation_1-auc:0.75111
# [470]	validation_0-auc:0.76604	validation_1-auc:0.75118
# [471]	validation_0-auc:0.76619	validation_1-auc:0.75135
# [472]	validation_0-auc:0.76623	validation_1-auc:0.75138
# [473]	validation_0-auc:0.76640	validation_1-auc:0.75155
# [474]	validation_0-auc:0.76643	validation_1-auc:0.75160
# [475]	validation_0-auc:0.76663	validation_1-auc:0.75181
# [476]	validation_0-auc:0.76665	validation_1-auc:0.75181
# [477]	validation_0-auc:0.76680	validation_1-auc:0.75198
# [478]	validation_0-auc:0.76681	validation_1-auc:0.75198
# [479]	validation_0-auc:0.76688	validation_1-auc:0.75205
# [480]	validation_0-auc:0.76701	validation_1-auc:0.75217
# [481]	validation_0-auc:0.76717	validation_1-auc:0.75235
# [482]	validation_0-auc:0.76725	validation_1-auc:0.75242
# [483]	validation_0-auc:0.76732	validation_1-auc:0.75249
# [484]	validation_0-auc:0.76745	validation_1-auc:0.75266
# [485]	validation_0-auc:0.76749	validation_1-auc:0.75268
# [486]	validation_0-auc:0.76759	validation_1-auc:0.75280
# [487]	validation_0-auc:0.76767	validation_1-auc:0.75288
# [488]	validation_0-auc:0.76774	validation_1-auc:0.75296
# [489]	validation_0-auc:0.76775	validation_1-auc:0.75296
# [490]	validation_0-auc:0.76786	validation_1-auc:0.75308
# [491]	validation_0-auc:0.76794	validation_1-auc:0.75316
# [492]	validation_0-auc:0.76810	validation_1-auc:0.75333
# [493]	validation_0-auc:0.76814	validation_1-auc:0.75338
# [494]	validation_0-auc:0.76822	validation_1-auc:0.75347
# [495]	validation_0-auc:0.76836	validation_1-auc:0.75362
# [496]	validation_0-auc:0.76843	validation_1-auc:0.75370
# [497]	validation_0-auc:0.76852	validation_1-auc:0.75380
# [498]	validation_0-auc:0.76865	validation_1-auc:0.75393
# [499]	validation_0-auc:0.76883	validation_1-auc:0.75413
# [500]	validation_0-auc:0.76887	validation_1-auc:0.75415
# [501]	validation_0-auc:0.76892	validation_1-auc:0.75420
# [502]	validation_0-auc:0.76902	validation_1-auc:0.75429
# [503]	validation_0-auc:0.76909	validation_1-auc:0.75437
# [504]	validation_0-auc:0.76914	validation_1-auc:0.75442
# [505]	validation_0-auc:0.76918	validation_1-auc:0.75448
# [506]	validation_0-auc:0.76930	validation_1-auc:0.75460
# [507]	validation_0-auc:0.76939	validation_1-auc:0.75471
# [508]	validation_0-auc:0.76954	validation_1-auc:0.75486
# [509]	validation_0-auc:0.76963	validation_1-auc:0.75495
# [510]	validation_0-auc:0.76968	validation_1-auc:0.75500
# [511]	validation_0-auc:0.76976	validation_1-auc:0.75507
# [512]	validation_0-auc:0.76980	validation_1-auc:0.75511
# [513]	validation_0-auc:0.76991	validation_1-auc:0.75521
# [514]	validation_0-auc:0.77005	validation_1-auc:0.75538
# [515]	validation_0-auc:0.77015	validation_1-auc:0.75548
# [516]	validation_0-auc:0.77020	validation_1-auc:0.75555
# [517]	validation_0-auc:0.77021	validation_1-auc:0.75557
# [518]	validation_0-auc:0.77026	validation_1-auc:0.75562
# [519]	validation_0-auc:0.77032	validation_1-auc:0.75568
# [520]	validation_0-auc:0.77042	validation_1-auc:0.75579
# [521]	validation_0-auc:0.77050	validation_1-auc:0.75588
# [522]	validation_0-auc:0.77056	validation_1-auc:0.75594
# [523]	validation_0-auc:0.77064	validation_1-auc:0.75603
# [524]	validation_0-auc:0.77065	validation_1-auc:0.75601
# [525]	validation_0-auc:0.77079	validation_1-auc:0.75615
# [526]	validation_0-auc:0.77084	validation_1-auc:0.75620
# [527]	validation_0-auc:0.77097	validation_1-auc:0.75635
# [528]	validation_0-auc:0.77106	validation_1-auc:0.75643
# [529]	validation_0-auc:0.77116	validation_1-auc:0.75653
# [530]	validation_0-auc:0.77130	validation_1-auc:0.75670
# [531]	validation_0-auc:0.77143	validation_1-auc:0.75685
# [532]	validation_0-auc:0.77152	validation_1-auc:0.75694
# [533]	validation_0-auc:0.77157	validation_1-auc:0.75699
# [534]	validation_0-auc:0.77163	validation_1-auc:0.75705
# [535]	validation_0-auc:0.77163	validation_1-auc:0.75707
# [536]	validation_0-auc:0.77171	validation_1-auc:0.75716
# [537]	validation_0-auc:0.77171	validation_1-auc:0.75717
# [538]	validation_0-auc:0.77183	validation_1-auc:0.75729
# [539]	validation_0-auc:0.77183	validation_1-auc:0.75731
# [540]	validation_0-auc:0.77184	validation_1-auc:0.75732
# [541]	validation_0-auc:0.77194	validation_1-auc:0.75741
# [542]	validation_0-auc:0.77202	validation_1-auc:0.75749
# [543]	validation_0-auc:0.77207	validation_1-auc:0.75753
# [544]	validation_0-auc:0.77214	validation_1-auc:0.75758
# [545]	validation_0-auc:0.77216	validation_1-auc:0.75761
# [546]	validation_0-auc:0.77229	validation_1-auc:0.75776
# [547]	validation_0-auc:0.77238	validation_1-auc:0.75783
# [548]	validation_0-auc:0.77246	validation_1-auc:0.75794
# [549]	validation_0-auc:0.77251	validation_1-auc:0.75802
# [550]	validation_0-auc:0.77262	validation_1-auc:0.75814
# [551]	validation_0-auc:0.77270	validation_1-auc:0.75822
# [552]	validation_0-auc:0.77278	validation_1-auc:0.75830
# [553]	validation_0-auc:0.77287	validation_1-auc:0.75839
# [554]	validation_0-auc:0.77295	validation_1-auc:0.75847
# [555]	validation_0-auc:0.77307	validation_1-auc:0.75859
# [556]	validation_0-auc:0.77305	validation_1-auc:0.75857
# [557]	validation_0-auc:0.77315	validation_1-auc:0.75866
# [558]	validation_0-auc:0.77318	validation_1-auc:0.75869
# [559]	validation_0-auc:0.77316	validation_1-auc:0.75867
# [560]	validation_0-auc:0.77318	validation_1-auc:0.75870
# [561]	validation_0-auc:0.77330	validation_1-auc:0.75882
# [562]	validation_0-auc:0.77337	validation_1-auc:0.75890
# [563]	validation_0-auc:0.77339	validation_1-auc:0.75891
# [564]	validation_0-auc:0.77343	validation_1-auc:0.75894
# [565]	validation_0-auc:0.77348	validation_1-auc:0.75900
# [566]	validation_0-auc:0.77358	validation_1-auc:0.75914
# [567]	validation_0-auc:0.77366	validation_1-auc:0.75923
# [568]	validation_0-auc:0.77375	validation_1-auc:0.75932
# [569]	validation_0-auc:0.77376	validation_1-auc:0.75934
# [570]	validation_0-auc:0.77384	validation_1-auc:0.75942
# [571]	validation_0-auc:0.77389	validation_1-auc:0.75947
# [572]	validation_0-auc:0.77401	validation_1-auc:0.75959
# [573]	validation_0-auc:0.77409	validation_1-auc:0.75966
# [574]	validation_0-auc:0.77417	validation_1-auc:0.75974
# [575]	validation_0-auc:0.77430	validation_1-auc:0.75986
# [576]	validation_0-auc:0.77437	validation_1-auc:0.75995
# [577]	validation_0-auc:0.77443	validation_1-auc:0.76002
# [578]	validation_0-auc:0.77450	validation_1-auc:0.76009
# [579]	validation_0-auc:0.77458	validation_1-auc:0.76019
# [580]	validation_0-auc:0.77461	validation_1-auc:0.76021
# [581]	validation_0-auc:0.77469	validation_1-auc:0.76030
# [582]	validation_0-auc:0.77475	validation_1-auc:0.76037
# [583]	validation_0-auc:0.77477	validation_1-auc:0.76038
# [584]	validation_0-auc:0.77486	validation_1-auc:0.76046
# [585]	validation_0-auc:0.77501	validation_1-auc:0.76063
# [586]	validation_0-auc:0.77511	validation_1-auc:0.76073
# [587]	validation_0-auc:0.77516	validation_1-auc:0.76079
# [588]	validation_0-auc:0.77519	validation_1-auc:0.76083
# [589]	validation_0-auc:0.77517	validation_1-auc:0.76080
# [590]	validation_0-auc:0.77526	validation_1-auc:0.76093
# [591]	validation_0-auc:0.77528	validation_1-auc:0.76094
# [592]	validation_0-auc:0.77534	validation_1-auc:0.76101
# [593]	validation_0-auc:0.77540	validation_1-auc:0.76105
# [594]	validation_0-auc:0.77550	validation_1-auc:0.76117
# [595]	validation_0-auc:0.77556	validation_1-auc:0.76124
# [596]	validation_0-auc:0.77562	validation_1-auc:0.76130
# [597]	validation_0-auc:0.77570	validation_1-auc:0.76139
# [598]	validation_0-auc:0.77581	validation_1-auc:0.76150
# [599]	validation_0-auc:0.77581	validation_1-auc:0.76150
# [600]	validation_0-auc:0.77591	validation_1-auc:0.76160
# [601]	validation_0-auc:0.77599	validation_1-auc:0.76167
# [602]	validation_0-auc:0.77598	validation_1-auc:0.76167
# [603]	validation_0-auc:0.77607	validation_1-auc:0.76176
# [604]	validation_0-auc:0.77609	validation_1-auc:0.76178
# [605]	validation_0-auc:0.77613	validation_1-auc:0.76184
# [606]	validation_0-auc:0.77617	validation_1-auc:0.76187
# [607]	validation_0-auc:0.77625	validation_1-auc:0.76194
# [608]	validation_0-auc:0.77625	validation_1-auc:0.76194
# [609]	validation_0-auc:0.77639	validation_1-auc:0.76207
# [610]	validation_0-auc:0.77635	validation_1-auc:0.76203
# [611]	validation_0-auc:0.77634	validation_1-auc:0.76203
# [612]	validation_0-auc:0.77641	validation_1-auc:0.76213
# [613]	validation_0-auc:0.77651	validation_1-auc:0.76223
# [614]	validation_0-auc:0.77656	validation_1-auc:0.76227
# [615]	validation_0-auc:0.77656	validation_1-auc:0.76228
# [616]	validation_0-auc:0.77658	validation_1-auc:0.76230
# [617]	validation_0-auc:0.77671	validation_1-auc:0.76243
# [618]	validation_0-auc:0.77679	validation_1-auc:0.76251
# [619]	validation_0-auc:0.77682	validation_1-auc:0.76253
# [620]	validation_0-auc:0.77684	validation_1-auc:0.76255
# [621]	validation_0-auc:0.77686	validation_1-auc:0.76259
# [622]	validation_0-auc:0.77689	validation_1-auc:0.76264
# [623]	validation_0-auc:0.77693	validation_1-auc:0.76266
# [624]	validation_0-auc:0.77699	validation_1-auc:0.76272
# [625]	validation_0-auc:0.77710	validation_1-auc:0.76282
# [626]	validation_0-auc:0.77719	validation_1-auc:0.76295
# [627]	validation_0-auc:0.77724	validation_1-auc:0.76301
# [628]	validation_0-auc:0.77733	validation_1-auc:0.76310
# [629]	validation_0-auc:0.77740	validation_1-auc:0.76316
# [630]	validation_0-auc:0.77740	validation_1-auc:0.76316
# [631]	validation_0-auc:0.77741	validation_1-auc:0.76316
# [632]	validation_0-auc:0.77746	validation_1-auc:0.76321
# [633]	validation_0-auc:0.77752	validation_1-auc:0.76329
# [634]	validation_0-auc:0.77756	validation_1-auc:0.76333
# [635]	validation_0-auc:0.77763	validation_1-auc:0.76340
# [636]	validation_0-auc:0.77770	validation_1-auc:0.76347
# [637]	validation_0-auc:0.77776	validation_1-auc:0.76354
# [638]	validation_0-auc:0.77778	validation_1-auc:0.76356
# [639]	validation_0-auc:0.77780	validation_1-auc:0.76357
# [640]	validation_0-auc:0.77780	validation_1-auc:0.76359
# [641]	validation_0-auc:0.77790	validation_1-auc:0.76370
# [642]	validation_0-auc:0.77794	validation_1-auc:0.76375
# [643]	validation_0-auc:0.77798	validation_1-auc:0.76379
# [644]	validation_0-auc:0.77802	validation_1-auc:0.76384
# [645]	validation_0-auc:0.77803	validation_1-auc:0.76385
# [646]	validation_0-auc:0.77805	validation_1-auc:0.76387
# [647]	validation_0-auc:0.77816	validation_1-auc:0.76400
# [648]	validation_0-auc:0.77819	validation_1-auc:0.76403
# [649]	validation_0-auc:0.77824	validation_1-auc:0.76409
# [650]	validation_0-auc:0.77836	validation_1-auc:0.76423
# [651]	validation_0-auc:0.77840	validation_1-auc:0.76426
# [652]	validation_0-auc:0.77848	validation_1-auc:0.76436
# [653]	validation_0-auc:0.77848	validation_1-auc:0.76437
# [654]	validation_0-auc:0.77852	validation_1-auc:0.76443
# [655]	validation_0-auc:0.77853	validation_1-auc:0.76443
# [656]	validation_0-auc:0.77865	validation_1-auc:0.76455
# [657]	validation_0-auc:0.77878	validation_1-auc:0.76470
# [658]	validation_0-auc:0.77888	validation_1-auc:0.76481
# [659]	validation_0-auc:0.77888	validation_1-auc:0.76482
# [660]	validation_0-auc:0.77898	validation_1-auc:0.76489
# [661]	validation_0-auc:0.77907	validation_1-auc:0.76499
# [662]	validation_0-auc:0.77911	validation_1-auc:0.76504
# [663]	validation_0-auc:0.77910	validation_1-auc:0.76502
# [664]	validation_0-auc:0.77912	validation_1-auc:0.76505
# [665]	validation_0-auc:0.77914	validation_1-auc:0.76506
# [666]	validation_0-auc:0.77917	validation_1-auc:0.76511
# [667]	validation_0-auc:0.77924	validation_1-auc:0.76517
# [668]	validation_0-auc:0.77932	validation_1-auc:0.76527
# [669]	validation_0-auc:0.77933	validation_1-auc:0.76531
# [670]	validation_0-auc:0.77934	validation_1-auc:0.76529
# [671]	validation_0-auc:0.77941	validation_1-auc:0.76535
# [672]	validation_0-auc:0.77943	validation_1-auc:0.76538
# [673]	validation_0-auc:0.77952	validation_1-auc:0.76547
# [674]	validation_0-auc:0.77959	validation_1-auc:0.76556
# [675]	validation_0-auc:0.77967	validation_1-auc:0.76565
# [676]	validation_0-auc:0.77970	validation_1-auc:0.76568
# [677]	validation_0-auc:0.77972	validation_1-auc:0.76571
# [678]	validation_0-auc:0.77978	validation_1-auc:0.76577
# [679]	validation_0-auc:0.77977	validation_1-auc:0.76576
# [680]	validation_0-auc:0.77989	validation_1-auc:0.76590
# [681]	validation_0-auc:0.77998	validation_1-auc:0.76599
# [682]	validation_0-auc:0.78003	validation_1-auc:0.76604
# [683]	validation_0-auc:0.78007	validation_1-auc:0.76609
# [684]	validation_0-auc:0.78014	validation_1-auc:0.76616
# [685]	validation_0-auc:0.78018	validation_1-auc:0.76623
# [686]	validation_0-auc:0.78022	validation_1-auc:0.76627
# [687]	validation_0-auc:0.78030	validation_1-auc:0.76636
# [688]	validation_0-auc:0.78036	validation_1-auc:0.76644
# [689]	validation_0-auc:0.78034	validation_1-auc:0.76642
# [690]	validation_0-auc:0.78036	validation_1-auc:0.76644
# [691]	validation_0-auc:0.78038	validation_1-auc:0.76648
# [692]	validation_0-auc:0.78044	validation_1-auc:0.76653
# [693]	validation_0-auc:0.78055	validation_1-auc:0.76666
# [694]	validation_0-auc:0.78069	validation_1-auc:0.76679
# [695]	validation_0-auc:0.78077	validation_1-auc:0.76688
# [696]	validation_0-auc:0.78079	validation_1-auc:0.76691
# [697]	validation_0-auc:0.78081	validation_1-auc:0.76693
# [698]	validation_0-auc:0.78083	validation_1-auc:0.76695
# [699]	validation_0-auc:0.78090	validation_1-auc:0.76701
# [700]	validation_0-auc:0.78097	validation_1-auc:0.76708
# [701]	validation_0-auc:0.78103	validation_1-auc:0.76715
# [702]	validation_0-auc:0.78109	validation_1-auc:0.76719
# [703]	validation_0-auc:0.78114	validation_1-auc:0.76724
# [704]	validation_0-auc:0.78118	validation_1-auc:0.76729
# [705]	validation_0-auc:0.78122	validation_1-auc:0.76733
# [706]	validation_0-auc:0.78121	validation_1-auc:0.76733
# [707]	validation_0-auc:0.78128	validation_1-auc:0.76741
# [708]	validation_0-auc:0.78135	validation_1-auc:0.76750
# [709]	validation_0-auc:0.78138	validation_1-auc:0.76752
# [710]	validation_0-auc:0.78143	validation_1-auc:0.76758
# [711]	validation_0-auc:0.78151	validation_1-auc:0.76767
# [712]	validation_0-auc:0.78157	validation_1-auc:0.76774
# [713]	validation_0-auc:0.78163	validation_1-auc:0.76779
# [714]	validation_0-auc:0.78168	validation_1-auc:0.76785
# [715]	validation_0-auc:0.78177	validation_1-auc:0.76794
# [716]	validation_0-auc:0.78179	validation_1-auc:0.76798
# [717]	validation_0-auc:0.78182	validation_1-auc:0.76800
# [718]	validation_0-auc:0.78189	validation_1-auc:0.76808
# [719]	validation_0-auc:0.78197	validation_1-auc:0.76816
# [720]	validation_0-auc:0.78198	validation_1-auc:0.76819
# [721]	validation_0-auc:0.78200	validation_1-auc:0.76822
# [722]	validation_0-auc:0.78202	validation_1-auc:0.76825
# [723]	validation_0-auc:0.78209	validation_1-auc:0.76831
# [724]	validation_0-auc:0.78214	validation_1-auc:0.76836
# [725]	validation_0-auc:0.78215	validation_1-auc:0.76838
# [726]	validation_0-auc:0.78221	validation_1-auc:0.76845
# [727]	validation_0-auc:0.78224	validation_1-auc:0.76849
# [728]	validation_0-auc:0.78235	validation_1-auc:0.76860
# [729]	validation_0-auc:0.78243	validation_1-auc:0.76868
# [730]	validation_0-auc:0.78242	validation_1-auc:0.76868
# [731]	validation_0-auc:0.78247	validation_1-auc:0.76872
# [732]	validation_0-auc:0.78251	validation_1-auc:0.76877
# [733]	validation_0-auc:0.78257	validation_1-auc:0.76884
# [734]	validation_0-auc:0.78260	validation_1-auc:0.76887
# [735]	validation_0-auc:0.78265	validation_1-auc:0.76894
# [736]	validation_0-auc:0.78272	validation_1-auc:0.76900
# [737]	validation_0-auc:0.78280	validation_1-auc:0.76910
# [738]	validation_0-auc:0.78286	validation_1-auc:0.76914
# [739]	validation_0-auc:0.78289	validation_1-auc:0.76918
# [740]	validation_0-auc:0.78301	validation_1-auc:0.76931
# [741]	validation_0-auc:0.78308	validation_1-auc:0.76940
# [742]	validation_0-auc:0.78320	validation_1-auc:0.76953
# [743]	validation_0-auc:0.78326	validation_1-auc:0.76958
# [744]	validation_0-auc:0.78330	validation_1-auc:0.76963
# [745]	validation_0-auc:0.78330	validation_1-auc:0.76965
# [746]	validation_0-auc:0.78339	validation_1-auc:0.76972
# [747]	validation_0-auc:0.78344	validation_1-auc:0.76979
# [748]	validation_0-auc:0.78349	validation_1-auc:0.76984
# [749]	validation_0-auc:0.78352	validation_1-auc:0.76988
# [750]	validation_0-auc:0.78360	validation_1-auc:0.76996
# [751]	validation_0-auc:0.78362	validation_1-auc:0.76999
# [752]	validation_0-auc:0.78364	validation_1-auc:0.77004
# [753]	validation_0-auc:0.78374	validation_1-auc:0.77013
# [754]	validation_0-auc:0.78382	validation_1-auc:0.77021
# [755]	validation_0-auc:0.78381	validation_1-auc:0.77021
# [756]	validation_0-auc:0.78385	validation_1-auc:0.77023
# [757]	validation_0-auc:0.78389	validation_1-auc:0.77028
# [758]	validation_0-auc:0.78397	validation_1-auc:0.77036
# [759]	validation_0-auc:0.78401	validation_1-auc:0.77041
# [760]	validation_0-auc:0.78406	validation_1-auc:0.77047
# [761]	validation_0-auc:0.78407	validation_1-auc:0.77048
# [762]	validation_0-auc:0.78409	validation_1-auc:0.77047
# [763]	validation_0-auc:0.78412	validation_1-auc:0.77050
# [764]	validation_0-auc:0.78412	validation_1-auc:0.77052
# [765]	validation_0-auc:0.78417	validation_1-auc:0.77056
# [766]	validation_0-auc:0.78424	validation_1-auc:0.77061
# [767]	validation_0-auc:0.78425	validation_1-auc:0.77064
# [768]	validation_0-auc:0.78429	validation_1-auc:0.77070
# [769]	validation_0-auc:0.78432	validation_1-auc:0.77072
# [770]	validation_0-auc:0.78434	validation_1-auc:0.77073
# [771]	validation_0-auc:0.78433	validation_1-auc:0.77074
# [772]	validation_0-auc:0.78439	validation_1-auc:0.77081
# [773]	validation_0-auc:0.78445	validation_1-auc:0.77087
# [774]	validation_0-auc:0.78451	validation_1-auc:0.77093
# [775]	validation_0-auc:0.78449	validation_1-auc:0.77091
# [776]	validation_0-auc:0.78456	validation_1-auc:0.77099
# [777]	validation_0-auc:0.78462	validation_1-auc:0.77105
# [778]	validation_0-auc:0.78468	validation_1-auc:0.77111
# [779]	validation_0-auc:0.78468	validation_1-auc:0.77113
# [780]	validation_0-auc:0.78472	validation_1-auc:0.77117
# [781]	validation_0-auc:0.78477	validation_1-auc:0.77122
# [782]	validation_0-auc:0.78483	validation_1-auc:0.77129
# [783]	validation_0-auc:0.78486	validation_1-auc:0.77131
# [784]	validation_0-auc:0.78490	validation_1-auc:0.77135
# [785]	validation_0-auc:0.78495	validation_1-auc:0.77141
# [786]	validation_0-auc:0.78499	validation_1-auc:0.77146
# [787]	validation_0-auc:0.78507	validation_1-auc:0.77153
# [788]	validation_0-auc:0.78510	validation_1-auc:0.77156
# [789]	validation_0-auc:0.78512	validation_1-auc:0.77159
# [790]	validation_0-auc:0.78516	validation_1-auc:0.77164
# [791]	validation_0-auc:0.78521	validation_1-auc:0.77170
# [792]	validation_0-auc:0.78525	validation_1-auc:0.77174
# [793]	validation_0-auc:0.78526	validation_1-auc:0.77175
# [794]	validation_0-auc:0.78531	validation_1-auc:0.77183
# [795]	validation_0-auc:0.78539	validation_1-auc:0.77191
# [796]	validation_0-auc:0.78540	validation_1-auc:0.77193
# [797]	validation_0-auc:0.78541	validation_1-auc:0.77194
# [798]	validation_0-auc:0.78540	validation_1-auc:0.77193
# [799]	validation_0-auc:0.78548	validation_1-auc:0.77201
# [800]	validation_0-auc:0.78553	validation_1-auc:0.77207
# [801]	validation_0-auc:0.78556	validation_1-auc:0.77212
# [802]	validation_0-auc:0.78558	validation_1-auc:0.77212
# [803]	validation_0-auc:0.78560	validation_1-auc:0.77214
# [804]	validation_0-auc:0.78563	validation_1-auc:0.77217
# [805]	validation_0-auc:0.78567	validation_1-auc:0.77221
# [806]	validation_0-auc:0.78569	validation_1-auc:0.77223
# [807]	validation_0-auc:0.78569	validation_1-auc:0.77223
# [808]	validation_0-auc:0.78577	validation_1-auc:0.77231
# [809]	validation_0-auc:0.78578	validation_1-auc:0.77234
# [810]	validation_0-auc:0.78585	validation_1-auc:0.77243
# [811]	validation_0-auc:0.78584	validation_1-auc:0.77241
# [812]	validation_0-auc:0.78584	validation_1-auc:0.77242
# [813]	validation_0-auc:0.78593	validation_1-auc:0.77249
# [814]	validation_0-auc:0.78592	validation_1-auc:0.77247
# [815]	validation_0-auc:0.78596	validation_1-auc:0.77252
# [816]	validation_0-auc:0.78600	validation_1-auc:0.77256
# [817]	validation_0-auc:0.78606	validation_1-auc:0.77260
# [818]	validation_0-auc:0.78607	validation_1-auc:0.77264
# [819]	validation_0-auc:0.78611	validation_1-auc:0.77269
# [820]	validation_0-auc:0.78610	validation_1-auc:0.77267
# [821]	validation_0-auc:0.78616	validation_1-auc:0.77274
# [822]	validation_0-auc:0.78619	validation_1-auc:0.77278
# [823]	validation_0-auc:0.78619	validation_1-auc:0.77278
# [824]	validation_0-auc:0.78623	validation_1-auc:0.77282
# [825]	validation_0-auc:0.78623	validation_1-auc:0.77283
# [826]	validation_0-auc:0.78626	validation_1-auc:0.77285
# [827]	validation_0-auc:0.78624	validation_1-auc:0.77284
# [828]	validation_0-auc:0.78631	validation_1-auc:0.77292
# [829]	validation_0-auc:0.78635	validation_1-auc:0.77295
# [830]	validation_0-auc:0.78646	validation_1-auc:0.77306
# [831]	validation_0-auc:0.78655	validation_1-auc:0.77315
# [832]	validation_0-auc:0.78656	validation_1-auc:0.77318
# [833]	validation_0-auc:0.78660	validation_1-auc:0.77322
# [834]	validation_0-auc:0.78666	validation_1-auc:0.77328
# [835]	validation_0-auc:0.78670	validation_1-auc:0.77331
# [836]	validation_0-auc:0.78674	validation_1-auc:0.77336
# [837]	validation_0-auc:0.78674	validation_1-auc:0.77336
# [838]	validation_0-auc:0.78680	validation_1-auc:0.77342
# [839]	validation_0-auc:0.78679	validation_1-auc:0.77341
# [840]	validation_0-auc:0.78684	validation_1-auc:0.77346
# [841]	validation_0-auc:0.78692	validation_1-auc:0.77356
# [842]	validation_0-auc:0.78696	validation_1-auc:0.77360
# [843]	validation_0-auc:0.78701	validation_1-auc:0.77364
# [844]	validation_0-auc:0.78704	validation_1-auc:0.77368
# [845]	validation_0-auc:0.78708	validation_1-auc:0.77370
# [846]	validation_0-auc:0.78707	validation_1-auc:0.77370
# [847]	validation_0-auc:0.78710	validation_1-auc:0.77373
# [848]	validation_0-auc:0.78712	validation_1-auc:0.77375
# [849]	validation_0-auc:0.78710	validation_1-auc:0.77374
# ...
# [1894]	validation_0-auc:0.80491	validation_1-auc:0.79311
# [1895]	validation_0-auc:0.80492	validation_1-auc:0.79310
# [1896]	validation_0-auc:0.80493	validation_1-auc:0.79311
# [1897]	validation_0-auc:0.80493	validation_1-auc:0.79312
# [1898]	validation_0-auc:0.80493	validation_1-auc:0.79312
# [1899]	validation_0-auc:0.80494	validation_1-auc:0.79314
# [1900]	validation_0-auc:0.80495	validation_1-auc:0.79315
# [1901]	validation_0-auc:0.80495	validation_1-auc:0.79314
# [1902]	validation_0-auc:0.80495	validation_1-auc:0.79316
# [1903]	validation_0-auc:0.80496	validation_1-auc:0.79316
# [1904]	validation_0-auc:0.80497	validation_1-auc:0.79318
# [1905]	validation_0-auc:0.80498	validation_1-auc:0.79319
# [1906]	validation_0-auc:0.80498	validation_1-auc:0.79319
# [1907]	validation_0-auc:0.80498	validation_1-auc:0.79319
# [1908]	validation_0-auc:0.80499	validation_1-auc:0.79319
# [1909]	validation_0-auc:0.80499	validation_1-auc:0.79320
# [1910]	validation_0-auc:0.80500	validation_1-auc:0.79320
# [1911]	validation_0-auc:0.80501	validation_1-auc:0.79321
# [1912]	validation_0-auc:0.80500	validation_1-auc:0.79321
# [1913]	validation_0-auc:0.80501	validation_1-auc:0.79321
# [1914]	validation_0-auc:0.80502	validation_1-auc:0.79322
# [1915]	validation_0-auc:0.80502	validation_1-auc:0.79321
# [1916]	validation_0-auc:0.80502	validation_1-auc:0.79322
# [1917]	validation_0-auc:0.80502	validation_1-auc:0.79323
# [1918]	validation_0-auc:0.80502	validation_1-auc:0.79323
# [1919]	validation_0-auc:0.80504	validation_1-auc:0.79324
# [1920]	validation_0-auc:0.80504	validation_1-auc:0.79324
# [1921]	validation_0-auc:0.80503	validation_1-auc:0.79325
# [1922]	validation_0-auc:0.80504	validation_1-auc:0.79326
# [1923]	validation_0-auc:0.80505	validation_1-auc:0.79326
# [1924]	validation_0-auc:0.80504	validation_1-auc:0.79326
# [1925]	validation_0-auc:0.80505	validation_1-auc:0.79327
# [1926]	validation_0-auc:0.80506	validation_1-auc:0.79327
# [1927]	validation_0-auc:0.80504	validation_1-auc:0.79327
# [1928]	validation_0-auc:0.80506	validation_1-auc:0.79327
# [1929]	validation_0-auc:0.80507	validation_1-auc:0.79326
# [1930]	validation_0-auc:0.80507	validation_1-auc:0.79327
# [1931]	validation_0-auc:0.80508	validation_1-auc:0.79327
# [1932]	validation_0-auc:0.80509	validation_1-auc:0.79328
# [1933]	validation_0-auc:0.80509	validation_1-auc:0.79329
# [1934]	validation_0-auc:0.80509	validation_1-auc:0.79329
# [1935]	validation_0-auc:0.80510	validation_1-auc:0.79330
# [1936]	validation_0-auc:0.80509	validation_1-auc:0.79330
# [1937]	validation_0-auc:0.80509	validation_1-auc:0.79330
# [1938]	validation_0-auc:0.80510	validation_1-auc:0.79330
# [1939]	validation_0-auc:0.80511	validation_1-auc:0.79330
# [1940]	validation_0-auc:0.80512	validation_1-auc:0.79331
# [1941]	validation_0-auc:0.80512	validation_1-auc:0.79331
# [1942]	validation_0-auc:0.80512	validation_1-auc:0.79331
# [1943]	validation_0-auc:0.80513	validation_1-auc:0.79332
# [1944]	validation_0-auc:0.80513	validation_1-auc:0.79332
# [1945]	validation_0-auc:0.80514	validation_1-auc:0.79334
# [1946]	validation_0-auc:0.80517	validation_1-auc:0.79335
# [1947]	validation_0-auc:0.80517	validation_1-auc:0.79337
# [1948]	validation_0-auc:0.80518	validation_1-auc:0.79339
# [1949]	validation_0-auc:0.80518	validation_1-auc:0.79338
# [1950]	validation_0-auc:0.80519	validation_1-auc:0.79339
# [1951]	validation_0-auc:0.80519	validation_1-auc:0.79340
# [1952]	validation_0-auc:0.80519	validation_1-auc:0.79341
# [1953]	validation_0-auc:0.80520	validation_1-auc:0.79342
# [1954]	validation_0-auc:0.80521	validation_1-auc:0.79343
# [1955]	validation_0-auc:0.80522	validation_1-auc:0.79345
# [1956]	validation_0-auc:0.80522	validation_1-auc:0.79346
# [1957]	validation_0-auc:0.80523	validation_1-auc:0.79346
# [1958]	validation_0-auc:0.80525	validation_1-auc:0.79347
# [1959]	validation_0-auc:0.80525	validation_1-auc:0.79348
# [1960]	validation_0-auc:0.80525	validation_1-auc:0.79348
# [1961]	validation_0-auc:0.80525	validation_1-auc:0.79347
# [1962]	validation_0-auc:0.80526	validation_1-auc:0.79348
# [1963]	validation_0-auc:0.80526	validation_1-auc:0.79349
# [1964]	validation_0-auc:0.80526	validation_1-auc:0.79348
# [1965]	validation_0-auc:0.80527	validation_1-auc:0.79349
# [1966]	validation_0-auc:0.80527	validation_1-auc:0.79350
# [1967]	validation_0-auc:0.80528	validation_1-auc:0.79351
# [1968]	validation_0-auc:0.80529	validation_1-auc:0.79352
# [1969]	validation_0-auc:0.80529	validation_1-auc:0.79352
# [1970]	validation_0-auc:0.80530	validation_1-auc:0.79352
# [1971]	validation_0-auc:0.80530	validation_1-auc:0.79353
# [1972]	validation_0-auc:0.80530	validation_1-auc:0.79353
# [1973]	validation_0-auc:0.80531	validation_1-auc:0.79354
# [1974]	validation_0-auc:0.80530	validation_1-auc:0.79354
# [1975]	validation_0-auc:0.80531	validation_1-auc:0.79356
# [1976]	validation_0-auc:0.80531	validation_1-auc:0.79356
# [1977]	validation_0-auc:0.80533	validation_1-auc:0.79357
# [1978]	validation_0-auc:0.80533	validation_1-auc:0.79358
# [1979]	validation_0-auc:0.80533	validation_1-auc:0.79358
# [1980]	validation_0-auc:0.80533	validation_1-auc:0.79358
# [1981]	validation_0-auc:0.80534	validation_1-auc:0.79359
# [1982]	validation_0-auc:0.80534	validation_1-auc:0.79358
# [1983]	validation_0-auc:0.80535	validation_1-auc:0.79359
# [1984]	validation_0-auc:0.80535	validation_1-auc:0.79360
# [1985]	validation_0-auc:0.80536	validation_1-auc:0.79361
# [1986]	validation_0-auc:0.80537	validation_1-auc:0.79362
# [1987]	validation_0-auc:0.80538	validation_1-auc:0.79362
# [1988]	validation_0-auc:0.80538	validation_1-auc:0.79363
# [1989]	validation_0-auc:0.80539	validation_1-auc:0.79364
# [1990]	validation_0-auc:0.80538	validation_1-auc:0.79364
# [1991]	validation_0-auc:0.80538	validation_1-auc:0.79363
# [1992]	validation_0-auc:0.80538	validation_1-auc:0.79365
# [1993]	validation_0-auc:0.80540	validation_1-auc:0.79365
# [1994]	validation_0-auc:0.80540	validation_1-auc:0.79365
# [1995]	validation_0-auc:0.80541	validation_1-auc:0.79367
# [1996]	validation_0-auc:0.80541	validation_1-auc:0.79366
# [1997]	validation_0-auc:0.80541	validation_1-auc:0.79366
# [1998]	validation_0-auc:0.80540	validation_1-auc:0.79366
# [1999]	validation_0-auc:0.80542	validation_1-auc:0.79367
# [2000]	validation_0-auc:0.80543	validation_1-auc:0.79368
# [2001]	validation_0-auc:0.80545	validation_1-auc:0.79370
# [2002]	validation_0-auc:0.80544	validation_1-auc:0.79370
# [2003]	validation_0-auc:0.80544	validation_1-auc:0.79370
# [2004]	validation_0-auc:0.80544	validation_1-auc:0.79369
# [2005]	validation_0-auc:0.80545	validation_1-auc:0.79370
# [2006]	validation_0-auc:0.80546	validation_1-auc:0.79371
# [2007]	validation_0-auc:0.80546	validation_1-auc:0.79371
# [2008]	validation_0-auc:0.80546	validation_1-auc:0.79372
# [2009]	validation_0-auc:0.80547	validation_1-auc:0.79372
# [2010]	validation_0-auc:0.80547	validation_1-auc:0.79373
# [2011]	validation_0-auc:0.80548	validation_1-auc:0.79374
# [2012]	validation_0-auc:0.80549	validation_1-auc:0.79375
# [2013]	validation_0-auc:0.80549	validation_1-auc:0.79374
# [2014]	validation_0-auc:0.80548	validation_1-auc:0.79374
# [2015]	validation_0-auc:0.80548	validation_1-auc:0.79375
# [2016]	validation_0-auc:0.80548	validation_1-auc:0.79376
# [2017]	validation_0-auc:0.80549	validation_1-auc:0.79375
# [2018]	validation_0-auc:0.80549	validation_1-auc:0.79376
# [2019]	validation_0-auc:0.80549	validation_1-auc:0.79377
# [2020]	validation_0-auc:0.80549	validation_1-auc:0.79376
# [2021]	validation_0-auc:0.80549	validation_1-auc:0.79377
# [2022]	validation_0-auc:0.80551	validation_1-auc:0.79377
# [2023]	validation_0-auc:0.80550	validation_1-auc:0.79378
# [2024]	validation_0-auc:0.80552	validation_1-auc:0.79378
# [2025]	validation_0-auc:0.80553	validation_1-auc:0.79380
# [2026]	validation_0-auc:0.80552	validation_1-auc:0.79380
# [2027]	validation_0-auc:0.80552	validation_1-auc:0.79379
# [2028]	validation_0-auc:0.80553	validation_1-auc:0.79380
# [2029]	validation_0-auc:0.80553	validation_1-auc:0.79380
# [2030]	validation_0-auc:0.80554	validation_1-auc:0.79380
# [2031]	validation_0-auc:0.80553	validation_1-auc:0.79380
# [2032]	validation_0-auc:0.80553	validation_1-auc:0.79381
# [2033]	validation_0-auc:0.80554	validation_1-auc:0.79383
# [2034]	validation_0-auc:0.80554	validation_1-auc:0.79382
# [2035]	validation_0-auc:0.80555	validation_1-auc:0.79383
# [2036]	validation_0-auc:0.80556	validation_1-auc:0.79384
# [2037]	validation_0-auc:0.80556	validation_1-auc:0.79384
# [2038]	validation_0-auc:0.80556	validation_1-auc:0.79384
# [2039]	validation_0-auc:0.80556	validation_1-auc:0.79385
# [2040]	validation_0-auc:0.80557	validation_1-auc:0.79385
# [2041]	validation_0-auc:0.80558	validation_1-auc:0.79386
# [2042]	validation_0-auc:0.80559	validation_1-auc:0.79387
# [2043]	validation_0-auc:0.80559	validation_1-auc:0.79387
# [2044]	validation_0-auc:0.80560	validation_1-auc:0.79388
# [2045]	validation_0-auc:0.80560	validation_1-auc:0.79388
# [2046]	validation_0-auc:0.80561	validation_1-auc:0.79389
# [2047]	validation_0-auc:0.80561	validation_1-auc:0.79390
# [2048]	validation_0-auc:0.80563	validation_1-auc:0.79391
# [2049]	validation_0-auc:0.80562	validation_1-auc:0.79390
# [2050]	validation_0-auc:0.80562	validation_1-auc:0.79391
# [2051]	validation_0-auc:0.80562	validation_1-auc:0.79391
# [2052]	validation_0-auc:0.80563	validation_1-auc:0.79392
# [2053]	validation_0-auc:0.80563	validation_1-auc:0.79391
# [2054]	validation_0-auc:0.80563	validation_1-auc:0.79392
# [2055]	validation_0-auc:0.80563	validation_1-auc:0.79392
# [2056]	validation_0-auc:0.80563	validation_1-auc:0.79393
# [2057]	validation_0-auc:0.80564	validation_1-auc:0.79394
# [2058]	validation_0-auc:0.80565	validation_1-auc:0.79394
# [2059]	validation_0-auc:0.80565	validation_1-auc:0.79395
# [2060]	validation_0-auc:0.80566	validation_1-auc:0.79395
# [2061]	validation_0-auc:0.80566	validation_1-auc:0.79397
# [2062]	validation_0-auc:0.80566	validation_1-auc:0.79396
# [2063]	validation_0-auc:0.80567	validation_1-auc:0.79397
# [2064]	validation_0-auc:0.80566	validation_1-auc:0.79397
# [2065]	validation_0-auc:0.80566	validation_1-auc:0.79397
# [2066]	validation_0-auc:0.80568	validation_1-auc:0.79398
# [2067]	validation_0-auc:0.80568	validation_1-auc:0.79399
# [2068]	validation_0-auc:0.80569	validation_1-auc:0.79400
# [2069]	validation_0-auc:0.80569	validation_1-auc:0.79399
# [2070]	validation_0-auc:0.80569	validation_1-auc:0.79399
# [2071]	validation_0-auc:0.80569	validation_1-auc:0.79400
# [2072]	validation_0-auc:0.80570	validation_1-auc:0.79401
# [2073]	validation_0-auc:0.80570	validation_1-auc:0.79400
# [2074]	validation_0-auc:0.80570	validation_1-auc:0.79400
# [2075]	validation_0-auc:0.80570	validation_1-auc:0.79401
# [2076]	validation_0-auc:0.80571	validation_1-auc:0.79402
# [2077]	validation_0-auc:0.80571	validation_1-auc:0.79402
# [2078]	validation_0-auc:0.80572	validation_1-auc:0.79403
# [2079]	validation_0-auc:0.80572	validation_1-auc:0.79403
# [2080]	validation_0-auc:0.80572	validation_1-auc:0.79404
# [2081]	validation_0-auc:0.80574	validation_1-auc:0.79405
# [2082]	validation_0-auc:0.80573	validation_1-auc:0.79405
# [2083]	validation_0-auc:0.80574	validation_1-auc:0.79406
# [2084]	validation_0-auc:0.80574	validation_1-auc:0.79406
# [2085]	validation_0-auc:0.80574	validation_1-auc:0.79406
# [2086]	validation_0-auc:0.80574	validation_1-auc:0.79407
# [2087]	validation_0-auc:0.80575	validation_1-auc:0.79408
# [2088]	validation_0-auc:0.80575	validation_1-auc:0.79409
# [2089]	validation_0-auc:0.80575	validation_1-auc:0.79409
# [2090]	validation_0-auc:0.80576	validation_1-auc:0.79410
# [2091]	validation_0-auc:0.80577	validation_1-auc:0.79410
# [2092]	validation_0-auc:0.80577	validation_1-auc:0.79411
# [2093]	validation_0-auc:0.80576	validation_1-auc:0.79411
# [2094]	validation_0-auc:0.80577	validation_1-auc:0.79411
# [2095]	validation_0-auc:0.80579	validation_1-auc:0.79413
# [2096]	validation_0-auc:0.80579	validation_1-auc:0.79413
# [2097]	validation_0-auc:0.80579	validation_1-auc:0.79413
# [2098]	validation_0-auc:0.80580	validation_1-auc:0.79413
# [2099]	validation_0-auc:0.80580	validation_1-auc:0.79414
# [2100]	validation_0-auc:0.80581	validation_1-auc:0.79414
# [2101]	validation_0-auc:0.80581	validation_1-auc:0.79415
# [2102]	validation_0-auc:0.80581	validation_1-auc:0.79415
# [2103]	validation_0-auc:0.80582	validation_1-auc:0.79415
# [2104]	validation_0-auc:0.80583	validation_1-auc:0.79417
# [2105]	validation_0-auc:0.80584	validation_1-auc:0.79417
# [2106]	validation_0-auc:0.80585	validation_1-auc:0.79418
# [2107]	validation_0-auc:0.80585	validation_1-auc:0.79419
# [2108]	validation_0-auc:0.80585	validation_1-auc:0.79419
# [2109]	validation_0-auc:0.80585	validation_1-auc:0.79420
# [2110]	validation_0-auc:0.80586	validation_1-auc:0.79420
# [2111]	validation_0-auc:0.80587	validation_1-auc:0.79421
# [2112]	validation_0-auc:0.80587	validation_1-auc:0.79422
# [2113]	validation_0-auc:0.80588	validation_1-auc:0.79423
# [2114]	validation_0-auc:0.80587	validation_1-auc:0.79423
# [2115]	validation_0-auc:0.80588	validation_1-auc:0.79424
# [2116]	validation_0-auc:0.80589	validation_1-auc:0.79424
# [2117]	validation_0-auc:0.80589	validation_1-auc:0.79425
# [2118]	validation_0-auc:0.80590	validation_1-auc:0.79425
# [2119]	validation_0-auc:0.80590	validation_1-auc:0.79426
# [2120]	validation_0-auc:0.80591	validation_1-auc:0.79427
# [2121]	validation_0-auc:0.80592	validation_1-auc:0.79428
# [2122]	validation_0-auc:0.80593	validation_1-auc:0.79430
# [2123]	validation_0-auc:0.80594	validation_1-auc:0.79431
# [2124]	validation_0-auc:0.80594	validation_1-auc:0.79431
# [2125]	validation_0-auc:0.80595	validation_1-auc:0.79432
# [2126]	validation_0-auc:0.80596	validation_1-auc:0.79434
# [2127]	validation_0-auc:0.80596	validation_1-auc:0.79434
# [2128]	validation_0-auc:0.80597	validation_1-auc:0.79434
# [2129]	validation_0-auc:0.80597	validation_1-auc:0.79434
# [2130]	validation_0-auc:0.80597	validation_1-auc:0.79435
# [2131]	validation_0-auc:0.80597	validation_1-auc:0.79435
# [2132]	validation_0-auc:0.80598	validation_1-auc:0.79436
# [2133]	validation_0-auc:0.80598	validation_1-auc:0.79436
# [2134]	validation_0-auc:0.80600	validation_1-auc:0.79437
# [2135]	validation_0-auc:0.80599	validation_1-auc:0.79437
# [2136]	validation_0-auc:0.80599	validation_1-auc:0.79438
# [2137]	validation_0-auc:0.80599	validation_1-auc:0.79438
# [2138]	validation_0-auc:0.80600	validation_1-auc:0.79439
# [2139]	validation_0-auc:0.80600	validation_1-auc:0.79439
# [2140]	validation_0-auc:0.80602	validation_1-auc:0.79440
# [2141]	validation_0-auc:0.80602	validation_1-auc:0.79440
# [2142]	validation_0-auc:0.80601	validation_1-auc:0.79440
# [2143]	validation_0-auc:0.80601	validation_1-auc:0.79440
# [2144]	validation_0-auc:0.80602	validation_1-auc:0.79441
# [2145]	validation_0-auc:0.80602	validation_1-auc:0.79441
# [2146]	validation_0-auc:0.80602	validation_1-auc:0.79441
# [2147]	validation_0-auc:0.80603	validation_1-auc:0.79442
# [2148]	validation_0-auc:0.80603	validation_1-auc:0.79443
# [2149]	validation_0-auc:0.80604	validation_1-auc:0.79443
# [2150]	validation_0-auc:0.80605	validation_1-auc:0.79444
# [2151]	validation_0-auc:0.80605	validation_1-auc:0.79444
# [2152]	validation_0-auc:0.80606	validation_1-auc:0.79445
# [2153]	validation_0-auc:0.80606	validation_1-auc:0.79446
# [2154]	validation_0-auc:0.80606	validation_1-auc:0.79446
# [2155]	validation_0-auc:0.80605	validation_1-auc:0.79447
# [2156]	validation_0-auc:0.80606	validation_1-auc:0.79447
# [2157]	validation_0-auc:0.80607	validation_1-auc:0.79448
# [2158]	validation_0-auc:0.80607	validation_1-auc:0.79448
# [2159]	validation_0-auc:0.80607	validation_1-auc:0.79447
# [2160]	validation_0-auc:0.80607	validation_1-auc:0.79448
# [2161]	validation_0-auc:0.80607	validation_1-auc:0.79448
# [2162]	validation_0-auc:0.80607	validation_1-auc:0.79448
# [2163]	validation_0-auc:0.80608	validation_1-auc:0.79449
# [2164]	validation_0-auc:0.80608	validation_1-auc:0.79449
# [2165]	validation_0-auc:0.80608	validation_1-auc:0.79450
# [2166]	validation_0-auc:0.80609	validation_1-auc:0.79451
# [2167]	validation_0-auc:0.80609	validation_1-auc:0.79450
# [2168]	validation_0-auc:0.80610	validation_1-auc:0.79451
# [2169]	validation_0-auc:0.80610	validation_1-auc:0.79450
# [2170]	validation_0-auc:0.80610	validation_1-auc:0.79450
# [2171]	validation_0-auc:0.80609	validation_1-auc:0.79450
# Roc Value:  (array([0.        , 0.20936914, 1.        ]), array([0.        , 0.66521502, 1.        ]), array([2, 1, 0]))

# %%
predicts = model.predict(test_data)

# %%
output = pd.DataFrame(predicts, columns = ['claim'])
output['id'] = test_data.index
output.to_csv('submission.csv', index=False)
